# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
path = "/home/zelenyy/storage/data/sri-thunderstorm/gidrometeor/mipt_aragats/"

# %%
files = os.listdir(path)

# %%
files
# Out:
# ['dens_array_interpolated_QSNOW_2016-06-11_11_00_00.npy',
#  'dens_array_interpolated_QGRAUP_2016-06-11_11_00_00.npy']

# %%
data = np.load(os.path.join(path, files[0]))

# %%
data.dtype
# Out:
# dtype('float32')

# %%
data.shape
# Out:
# (395,)

# %%
plt.plot(data, label=files[0])
plt.legend();
